# %%
# test_calculo.py
def soma(a, b):
    return a + b

def test_soma():
    assert soma(2, 3) == 5

# %% [markdown]
# No terminal teste

# %%
pytest test_calculo.py
# Out:
#   File "<ipython-input-2-fbf858cf249d>", line 1
#     pytest test_calculo.py
#            ^
# SyntaxError: invalid syntax
