# %%
bash
# Criar um projeto Scrapy
scrapy startproject meu_spider

# Dentro do projeto, criar um spider
scrapy genspider exemplo_spider example.com

# %% [markdown]
# Dentro do exemplo_spider.py:

# %%
import scrapy

class ExemploSpider(scrapy.Spider):
    name = 'exemplo'
    start_urls = ['http://quotes.toscrape.com']

    def parse(self, response):
        for quote in response.css('div.quote'):
            yield {
                'texto': quote.css('span.text::text').get(),
                'autor': quote.css('span small::text').get(),
            }
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-158ae3efb697> in <cell line: 0>()
# ----> 1 import scrapy
#       2
#       3 class ExemploSpider(scrapy.Spider):
#       4     name = 'exemplo'
#       5     start_urls = ['http://quotes.toscrape.com']
#
# ModuleNotFoundError: No module named 'scrapy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
