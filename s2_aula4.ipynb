# %%
import pandas as pd

# %%
dados = {
    'Nome': ['João', 'Maria', 'Pedro', 'Ana','Bia'],
    'Idade': [17, 16, 15, 16,17],
    'Matematica': [9, 9, 4, 7,5],
    'Fisica':[8,9,6,8,4],
    'Historia': [10,7, 6, 7,5],
    'Geografia':[8,9,5,6,6],
}

# Criar DataFrame a partir do dicionário
df = pd.DataFrame(dados)

# Exibir DataFrame
df
# Out:
#     Nome  Idade  Matematica  Fisica  Historia  Geografia
# 0   João     17           9       8        10          8
# 1  Maria     16           9       9         7          9
# 2  Pedro     15           4       6         6          5
# 3    Ana     16           7       8         7          6
# 4    Bia     17           5       4         5          6
